# %%
import pfmanager.engine as pm
import pfmanager.currency as cu
from datetime import date

# %%
pf=pm.Portfolio("De Giro")
acc=pm.Account("Cuenta de accciones")
acc.register_portfolio(pf)

# %%
pf.register_asset(pm.AssetEquity("Telefónica SA","EUR","TEF.MC"))
pf.register_asset(pm.AssetEquity("Medical Properties","USD","MPW"))
pf.register_asset(pm.AssetEquity("Apple","USD","AAPL"))

# %%
tr1 = pm.TransactionBuy(10,cu.Currency(100,"USD",80,"EUR"),cu.Currency(2,"USD",1.5,"EUR"),date_transaction=date(2021,5,3) )
pf.get_asset(symbol="AAPL").register_transaction(tr1)

# %%
tr2 = pm.TransactionBuy(20,cu.Currency(50),cu.Currency(2.5),date_transaction=date(2020,8,4) )
pf.get_asset(symbol="TEF.MC").register_transaction(tr2)

# %%
tr3 = pm.TransactionBuy(9,cu.Currency(150,"USD",120,"EUR"),cu.Currency(1,"USD",0.7,"EUR"),date_transaction=date(2021,7,7) )
pf.get_asset(symbol="MPW").register_transaction(tr3)

# %%
tr4 = pm.TransactionSell(5,cu.Currency(140,"USD",130,"EUR"),cu.Currency(2,"USD",1.5,"EUR"),date_transaction=date(2021,12,1) )
pf.get_asset(symbol="MPW").register_transaction(tr4)

# %%
tr5 = pm.TransactionSell(10,cu.Currency(110,"USD",100,"EUR"),cu.Currency(2,"USD",1.5,"EUR"),date_transaction=date(2021,12,2) )
pf.get_asset(symbol="AAPL").register_transaction(tr5)

# %%
pf.update_portfolio( update_assets=True)

# %%
pf.get_assets_info_dataframe()
# Out:
#                       Name  Shares  Market Value  TOTAL BENEFIT  \
# TEF.MC       Telefónica SA      20     78.109999    -924.390001
# MPW     Medical Properties       4     83.051567    -349.148433
# AAPL                 Apple       0      0.000000     197.000000
#
#         POTENCIAL BENEFIT  P.B. relative  Pot. Currency Benefit  \
# TEF.MC        -921.890001      -0.921890                   0.00
# MPW           -396.948433      -0.826976                  51.36
# AAPL             0.000000       0.000000                   0.00
#
#         Pot. Product Benefit  CURRENT BENEFIT  Curr. Currency Benefit  \
# TEF.MC           -921.890001             -2.5                0.000000
# MPW              -448.308433             47.8               96.428571
# AAPL                0.000000            197.0              109.090909
#
#         Curr. Product Benefit
# TEF.MC              -2.500000
# MPW                -48.628571
# AAPL                87.909091

# %%
acc.get_list_of_records_dataframe()
# Out:
#           Date Currency  Prev. Balance  Cash Flow  Next Balance  \
# 0   2020-08-04      EUR            0.0    -1000.0       -1000.0
# 1   2020-08-04      EUR        -1000.0       -2.5       -1002.5
# 2   2021-05-03      EUR        -1002.5     -800.0       -1802.5
# 3   2021-05-03      USD            0.0     1000.0        1000.0
# 4   2021-05-03      USD         1000.0    -1000.0           0.0
# 5   2021-05-03      EUR        -1802.5       -1.5       -1804.0
# 6   2021-07-07      EUR        -1804.0    -1080.0       -2884.0
# 7   2021-07-07      USD            0.0     1350.0        1350.0
# 8   2021-07-07      USD         1350.0    -1350.0           0.0
# 9   2021-07-07      EUR        -2884.0       -0.7       -2884.7
# 10  2021-12-01      USD            0.0      700.0         700.0
# 11  2021-12-01      USD          700.0     -700.0           0.0
# 12  2021-12-01      EUR        -2884.7      650.0       -2234.7
# 13  2021-12-01      EUR        -2234.7       -1.5       -2236.2
# 14  2021-12-02      USD            0.0     1100.0        1100.0
# 15  2021-12-02      USD         1100.0    -1100.0           0.0
# 16  2021-12-02      EUR        -2236.2     1000.0       -1236.2
# 17  2021-12-02      EUR        -1236.2       -1.5       -1237.7
#
#               Type Description
# 0              Buy
# 1      Commissions
# 2   Money exchange
# 3   Money exchange
# 4              Buy
# 5      Commissions
# 6   Money exchange
# 7   Money exchange
# 8              Buy
# 9      Commissions
# 10            Sell
# 11  Money exchange
# 12  Money exchange
# 13     Commissions
# 14            Sell
# 15  Money exchange
# 16  Money exchange
# 17     Commissions
