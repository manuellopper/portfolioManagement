# %%
import pandas as pd

# %% [markdown]
# La siguiente línea funciona después de haber descargado el libro de Google como excel, limpiando filas y columnas con datos que no quiero que aparezcan y guardando como .csv desde excel.

# %%
datos=pd.read_csv("Operaciones.csv", sep=";",header=0,index_col=False,parse_dates=[0],infer_datetime_format=True,dayfirst=True,decimal=",",thousands=".")

# %%
datos.dtypes
# Out:
# Fecha                  datetime64[ns]
# Cartera                        object
# Valor                          object
# Moneda                         object
# TIKR                           object
# Operación                      object
# Unidades                      float64
# Precio unitario               float64
# Comisiones                    float64
# Precio unitario (€)           float64
# Comisiones (€)                float64
# Retenciones (€)               float64
# dtype: object

# %%
datos
# Out:
#          Fecha Cartera                      Valor Moneda    TIKR Operación  \
# 0   2017-08-21  Degiro   Medical Properties Trust    USD     MPW       BUY
# 1   2017-08-22  Degiro   Medical Properties Trust    USD     MPW       BUY
# 2   2017-10-13  Degiro   Medical Properties Trust    USD     MPW       DIV
# 3   2017-10-13  Degiro   Medical Properties Trust    USD     MPW      SELL
# 4   2017-10-13  Degiro  Omega Heathcare Inversors    USD     OHI       BUY
# ..         ...     ...                        ...    ...     ...       ...
# 379 2021-11-08  Degiro           Tencent Holdings    EUR    NNND       BUY
# 380 2021-11-08  Degiro                     Danone    EUR  EPA:BN       BUY
# 381 2021-11-08  Degiro                      Merck    USD     MRK       BUY
# 382 2021-11-08  Degiro      Alibaba Holding Group    USD    BABA       BUY
# 383 2021-12-10  Degiro                   Meredith    USD     MDP      SELL
#
#      Unidades  Precio unitario  Comisiones  Precio unitario (€)  \
# 0        35.0            12.54        0.73                10.64
# 1        44.0            12.80        0.76                10.88
# 2         1.0            18.96        0.00                16.03
# 3        79.0            13.16        0.91                11.13
# 4        33.0            31.65        0.71                26.77
# ..        ...              ...         ...                  ...
# 379       3.0            52.80        3.90                52.80
# 380       1.0            53.41        4.19                53.41
# 381       1.0            72.90        0.00                64.54
# 382       2.0           123.47        0.00               109.31
# 383       6.0            59.17        0.00                52.28
#
#      Comisiones (€)  Retenciones (€)
# 0              0.62              NaN
# 1              0.65              NaN
# 2              0.00              2.4
# 3              0.77              NaN
# 4              0.60              NaN
# ..              ...              ...
# 379            3.90              0.0
# 380            4.19              0.0
# 381            0.00              0.0
# 382            0.00              0.0
# 383            0.00              0.0
#
# [384 rows x 12 columns]

# %%
datos.to_csv("Proc_Operaciones.csv",index=False)

# %%
datos2=pd.read_csv("Proc_Operaciones.csv",parse_dates=[0])

# %%
datos2
# Out:
#          Fecha Cartera                      Valor Moneda    TIKR Operación  \
# 0   2017-08-21  Degiro   Medical Properties Trust    USD     MPW       BUY
# 1   2017-08-22  Degiro   Medical Properties Trust    USD     MPW       BUY
# 2   2017-10-13  Degiro   Medical Properties Trust    USD     MPW       DIV
# 3   2017-10-13  Degiro   Medical Properties Trust    USD     MPW      SELL
# 4   2017-10-13  Degiro  Omega Heathcare Inversors    USD     OHI       BUY
# ..         ...     ...                        ...    ...     ...       ...
# 379 2021-11-08  Degiro           Tencent Holdings    EUR    NNND       BUY
# 380 2021-11-08  Degiro                     Danone    EUR  EPA:BN       BUY
# 381 2021-11-08  Degiro                      Merck    USD     MRK       BUY
# 382 2021-11-08  Degiro      Alibaba Holding Group    USD    BABA       BUY
# 383 2021-12-10  Degiro                   Meredith    USD     MDP      SELL
#
#      Unidades  Precio unitario  Comisiones  Precio unitario (€)  \
# 0        35.0            12.54        0.73                10.64
# 1        44.0            12.80        0.76                10.88
# 2         1.0            18.96        0.00                16.03
# 3        79.0            13.16        0.91                11.13
# 4        33.0            31.65        0.71                26.77
# ..        ...              ...         ...                  ...
# 379       3.0            52.80        3.90                52.80
# 380       1.0            53.41        4.19                53.41
# 381       1.0            72.90        0.00                64.54
# 382       2.0           123.47        0.00               109.31
# 383       6.0            59.17        0.00                52.28
#
#      Comisiones (€)  Retenciones (€)
# 0              0.62              NaN
# 1              0.65              NaN
# 2              0.00              2.4
# 3              0.77              NaN
# 4              0.60              NaN
# ..              ...              ...
# 379            3.90              0.0
# 380            4.19              0.0
# 381            0.00              0.0
# 382            0.00              0.0
# 383            0.00              0.0
#
# [384 rows x 12 columns]

# %%
datos2.dtypes
# Out:
# Fecha                  datetime64[ns]
# Cartera                        object
# Valor                          object
# Moneda                         object
# TIKR                           object
# Operación                      object
# Unidades                      float64
# Precio unitario               float64
# Comisiones                    float64
# Precio unitario (€)           float64
# Comisiones (€)                float64
# Retenciones (€)               float64
# dtype: object
