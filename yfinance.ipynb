# %%
import yfinance as yf
import numpy as np
import pandas as pd
from pandas_datareader import data

# %%
msft = yf.Ticker("MSFT")

# %%
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 181000,
# ...

# %%
msft.info["currency"]
# Out:
# 'USD'

# %%
msft.info["bid"]
# Out:
# 336.32

# %%
msft.info["ask"]
# Out:
# 336.79

# %%
msft.info["dayLow"]
# Out:
# 335.85

# %%
msft.info["dayHigh"]
# Out:
# 339.35

# %%
msft.info["regularMarketPrice"]
# Out:
# 336.32

# %%
type(msft)
# Out:
# yfinance.ticker.Ticker

# %%
dir(msft)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_analysis',
#  '_balancesheet',
#  '_base_url',
#  '_calendar',
#  '_cashflow',
#  '_download_options',
#  '_earnings',
#  '_expirations',
#  '_financials',
#  '_fundamentals',
#  '_get_fundamentals',
#  '_history',
#  '_info',
#  '_institutional_holders',
#  '_isin',
#  '_major_holders',
#  '_mutualfund_holders',
#  '_news',
#  '_options2df',
#  '_recommendations',
#  '_scrape_url',
#  '_shares',
#  '_sustainability',
#  'actions',
#  'analysis',
#  'balance_sheet',
#  'balancesheet',
#  'calendar',
#  'cashflow',
#  'dividends',
#  'earnings',
#  'financials',
# ...

# %%
hist=msft.history(period="max")
hist
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1986-03-13    0.055898    0.064119    0.055898    0.061378  1031788800
# 1986-03-14    0.061378    0.064667    0.061378    0.063570   308160000
# 1986-03-17    0.063570    0.065215    0.063570    0.064667   133171200
# 1986-03-18    0.064667    0.065215    0.062474    0.063022    67766400
# 1986-03-19    0.063022    0.063570    0.061378    0.061926    47894400
# ...                ...         ...         ...         ...         ...
# 2021-12-27  335.459991  342.480011  335.429993  342.450012    19947000
# 2021-12-28  343.149994  343.809998  340.320007  341.250000    15661500
# 2021-12-29  341.299988  344.299988  339.679993  341.950012    15042000
# 2021-12-30  341.910004  343.130005  338.820007  339.320007    15994500
# 2021-12-31  338.510010  339.359985  335.850006  336.320007    17986600
#
#             Dividends  Stock Splits
# Date
# 1986-03-13        0.0           0.0
# ...

# %%
type(hist)
# Out:
# pandas.core.frame.DataFrame

# %%
hist.to_csv("msft.csv")

# %%
type(hist.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
sub=hist["2021-01-01":"2021-11-30"]

# %%
sub
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2021-01-04  220.680196  221.146290  213.024368  215.880432  37130100
# 2021-01-05  215.453990  216.703525  213.906960  216.088669  23823000
# 2021-01-06  210.406305  214.690401  210.178221  210.485641  35930700
# 2021-01-07  212.260747  217.516693  211.933503  216.475418  27694500
# 2021-01-08  216.862184  218.746399  215.225906  217.794373  22956200
# ...                ...         ...         ...         ...       ...
# 2021-11-23  337.049988  339.450012  333.559998  337.679993  30427600
# 2021-11-24  336.279999  338.160004  333.910004  337.910004  21661300
# 2021-11-26  334.350006  337.929993  328.119995  329.679993  24217200
# 2021-11-29  334.940002  339.029999  334.739990  336.630005  28563500
# 2021-11-30  335.320007  337.779999  328.989990  330.589996  42885600
#
#             Dividends  Stock Splits
# Date
# 2021-01-04        0.0           0.0
# 2021-01-05        0.0           0.0
# ...

# %%
sub.index
# Out:
# DatetimeIndex(['2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07',
#                '2021-01-08', '2021-01-11', '2021-01-12', '2021-01-13',
#                '2021-01-14', '2021-01-15',
#                ...
#                '2021-11-16', '2021-11-17', '2021-11-18', '2021-11-19',
#                '2021-11-22', '2021-11-23', '2021-11-24', '2021-11-26',
#                '2021-11-29', '2021-11-30'],
#               dtype='datetime64[ns]', name='Date', length=230, freq=None)

# %%
resp=sub.index=="2021-11-30"

# %%
resp
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
sub[resp]
# Out:
#                   Open        High        Low       Close    Volume  \
# Date
# 2021-11-30  335.320007  337.779999  328.98999  330.589996  42885600
#
#             Dividends  Stock Splits
# Date
# 2021-11-30        0.0           0.0

# %%
a=sub[sub.index=="2021-11-30"]
a
# Out:
#                   Open        High        Low       Close    Volume  \
# Date
# 2021-11-30  335.320007  337.779999  328.98999  330.589996  42885600
#
#             Dividends  Stock Splits
# Date
# 2021-11-30        0.0           0.0

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1 entries, 2021-11-30 to 2021-11-30
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          1 non-null      float64
#  1   High          1 non-null      float64
#  2   Low           1 non-null      float64
#  3   Close         1 non-null      float64
#  4   Volume        1 non-null      int64
#  5   Dividends     1 non-null      float64
#  6   Stock Splits  1 non-null      float64
# dtypes: float64(6), int64(1)
# memory usage: 64.0 bytes

# %%
b=sub[sub.index=="2021-11-31"]
b
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Dividends, Stock Splits]
# Index: []

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 0 entries
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          0 non-null      float64
#  1   High          0 non-null      float64
#  2   Low           0 non-null      float64
#  3   Close         0 non-null      float64
#  4   Volume        0 non-null      int64
#  5   Dividends     0 non-null      float64
#  6   Stock Splits  0 non-null      float64
# dtypes: float64(6), int64(1)
# memory usage: 0.0 bytes

# %%
actions=msft.actions
actions
# Out:
#             Dividends  Stock Splits
# Date
# 1987-09-21       0.00           2.0
# 1990-04-16       0.00           2.0
# 1991-06-27       0.00           1.5
# 1992-06-15       0.00           1.5
# 1994-05-23       0.00           2.0
# ...               ...           ...
# 2020-11-18       0.56           0.0
# 2021-02-17       0.56           0.0
# 2021-05-19       0.56           0.0
# 2021-08-18       0.56           0.0
# 2021-11-17       0.62           0.0
#
# [81 rows x 2 columns]

# %%
type(actions)
# Out:
# pandas.core.frame.DataFrame

# %%
dividends=msft.dividends
dividends
# Out:
# Date
# 2003-02-19    0.08
# 2003-10-15    0.16
# 2004-08-23    0.08
# 2004-11-15    3.08
# 2005-02-15    0.08
#               ...
# 2020-11-18    0.56
# 2021-02-17    0.56
# 2021-05-19    0.56
# 2021-08-18    0.56
# 2021-11-17    0.62
# Name: Dividends, Length: 72, dtype: float64

# %%
type(dividends)
# Out:
# pandas.core.series.Series

# %%
financials=msft.financials
financials
# Out:
#                                             2021-06-30      2020-06-30  \
# Research Development                     20716000000.0   19269000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        71102000000.0   53036000000.0
# Minority Interest                                 None            None
# Net Income                               61271000000.0   44281000000.0
# Selling General Administrative           25224000000.0   24523000000.0
# Gross Profit                            115856000000.0   96937000000.0
# Ebit                                     69916000000.0   53145000000.0
# Operating Income                         69916000000.0   53145000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -2330000000.0   -2591000000.0
# Extraordinary Items                               None            None
# ...

# %%
type(financials)
# Out:
# pandas.core.frame.DataFrame

# %%
qfinancials=msft.quarterly_financials
qfinancials
# Out:
#                                            2021-09-30     2021-06-30  \
# Research Development                     5599000000.0   5687000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       20524000000.0  19405000000.0
# Minority Interest                                None           None
# Net Income                              20505000000.0  16458000000.0
# Selling General Administrative           5834000000.0   7379000000.0
# Gross Profit                            31671000000.0  32161000000.0
# Ebit                                    20238000000.0  19095000000.0
# Operating Income                        20238000000.0  19095000000.0
# Other Operating Expenses                         None           None
# Interest Expense                         -535000000.0   -549000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %%
holders=msft.major_holders
holders
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  71.90%       % of Shares Held by Institutions
# 2  71.94%        % of Float Held by Institutions
# 3    5400  Number of Institutions Holding Shares

# %%
type(holders)
# Out:
# pandas.core.frame.DataFrame

# %%
iholders=msft.institutional_holders
iholders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  613781686    2021-09-29  0.0818
# 1                     Blackrock Inc.  507117032    2021-09-29  0.0675
# 2           State Street Corporation  294432926    2021-09-29  0.0392
# 3                           FMR, LLC  215731468    2021-09-29  0.0287
# 4      Price (T.Rowe) Associates Inc  197579453    2021-09-29  0.0263
# 5      Geode Capital Management, LLC  126079812    2021-09-29  0.0168
# 6            Capital World Investors  110359787    2021-09-29  0.0147
# 7  Capital Research Global Investors   94282634    2021-09-29  0.0126
# 8    Capital International Investors   91901445    2021-09-29  0.0122
# 9         Northern Trust Corporation   89592127    2021-09-29  0.0119
#
#           Value
# 0  173037332917
# 1  142966433661
# 2   83006530497
# 3   60819015458
# 4   55701599389
# 5   35544420599
# 6   31112631151
# 7   26580160177
# 8   25908855374
# 9   25257812443

# %%
bsheet=msft.balance_sheet
qbsheet=msft.quarterly_balance_sheet
bsheet
# Out:
#                                     2021-06-30    2020-06-30    2019-06-30  \
# Intangible Assets                 7.800000e+09  7.038000e+09  7.750000e+09
# Total Liab                        1.917910e+11  1.830070e+11  1.842260e+11
# Total Stockholder Equity          1.419880e+11  1.183040e+11  1.023300e+11
# Other Current Liab                5.261200e+10  4.600100e+10  4.586000e+10
# Total Assets                      3.337790e+11  3.013110e+11  2.865560e+11
# Common Stock                      8.311100e+10  8.055200e+10  7.852000e+10
# Other Current Assets              1.347100e+10  1.151700e+10  1.013300e+10
# Retained Earnings                 5.705500e+10  3.456600e+10  2.415000e+10
# Other Liab                        3.168100e+10  3.449200e+10  3.569900e+10
# Good Will                         4.971100e+10  4.335100e+10  4.202600e+10
# Treasury Stock                    1.822000e+09  3.186000e+09 -3.400000e+08
# ...

# %%
cashf=msft.cashflow
qcashf=msft.quarterly_cashflow
cashf
# Out:
#                                              2021-06-30    2020-06-30  \
# Investments                                2.876000e+09  6.980000e+09
# Change To Liabilities                      7.431000e+09  5.230000e+09
# Total Cashflows From Investing Activities -2.757700e+10 -1.222300e+10
# Net Borrowings                            -3.750000e+09 -5.518000e+09
# Total Cash From Financing Activities      -4.848600e+10 -4.603100e+10
# Change To Operating Activities             1.160000e+09 -6.730000e+08
# Issuance Of Stock                          1.693000e+09  1.343000e+09
# Net Income                                 6.127100e+10  4.428100e+10
# Change In Cash                             6.480000e+08  2.220000e+09
# Repurchase Of Stock                       -2.738500e+10 -2.296800e+10
# Effect Of Exchange Rate                   -2.900000e+07 -2.010000e+08
# Total Cash From Operating Activities       7.674000e+10  6.067500e+10
# ...

# %%
earnings=msft.earnings
qearnings=msft.quarterly_earnings
earnings
# Out:
#            Revenue     Earnings
# Year
# 2018  110360000000  16571000000
# 2019  125843000000  39240000000
# 2020  143015000000  44281000000
# 2021  168088000000  61271000000

# %%
msft.info["financialCurrency"]
# Out:
# 'USD'

# %%
sust=msft.sustainability
sust
# Out:
#                                      Value
# 2021-9
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                           8.06
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                      None
# peerCount                               99
# governanceScore                       4.73
# environmentPercentile                 None
# animalTesting                        False
# tobacco                              False
# totalEsg                             13.26
# highestControversy                       3
# esgPerformance                  UNDER_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...

# %%
msft.info["sector"]
# Out:
# 'Technology'

# %%
rec=msft.recommendations
rec
# Out:
#                                Firm       To Grade From Grade Action
# Date
# 2012-03-16 08:19:00  Argus Research            Buy                up
# 2012-03-19 14:00:00  Hilliard Lyons  Long-Term Buy              main
# 2012-03-22 07:03:00  Morgan Stanley     Overweight              main
# 2012-04-03 11:53:00             UBS            Buy              main
# 2012-04-20 06:18:00   Deutsche Bank            Buy              main
# ...                             ...            ...        ...    ...
# 2021-10-27 13:41:53        Barclays     Overweight              main
# 2021-10-27 13:56:33  Morgan Stanley     Overweight              main
# 2021-10-28 14:55:44       Citigroup            Buy              main
# 2021-11-02 09:45:19   Deutsche Bank            Buy              init
# 2021-12-22 10:02:34      SMBC Nikko     Outperform              init
#
# [359 rows x 4 columns]

# %%
cal=msft.calendar
cal
# Out:
#                                     0                    1
# Earnings Date     2022-01-24 10:59:00  2022-01-28 12:00:00
# Earnings Average                 2.31                 2.31
# Earnings Low                     2.27                 2.27
# Earnings High                    2.46                 2.46
# Revenue Average           50873900000          50873900000
# Revenue Low               50536700000          50536700000
# Revenue High              51800000000          51800000000

# %%
isin=msft.isin
isin
# Out:
# 'US5949181045'

# %%
type(isin)
# Out:
# str

# %%
op=msft.options
op
# Out:
# ('2022-01-07',
#  '2022-01-14',
#  '2022-01-21',
#  '2022-01-28',
#  '2022-02-04',
#  '2022-02-18',
#  '2022-03-18',
#  '2022-04-14',
#  '2022-06-17',
#  '2022-07-15',
#  '2022-09-16',
#  '2023-01-20',
#  '2023-03-17',
#  '2023-06-16',
#  '2024-01-19')

# %%
type(op)
# Out:
# tuple

# %%
news=msft.news
news
# Out:
# [{'uuid': '89094498-0c7a-33d3-9f02-c3180d524082',
#   'title': 'Making Money With NFTs Without Owning One',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/89094498-0c7a-33d3-9f02-c3180d524082/making-money-with-nfts.html',
#   'providerPublishTime': 1641049200,
#   'type': 'STORY'},
#  {'uuid': '117bb9b9-95ac-3bfc-b387-41e3e48c4c27',
#   'title': '2 Breakout Growth Stocks You Can Buy and Hold for the Next Decade',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/117bb9b9-95ac-3bfc-b387-41e3e48c4c27/2-breakout-growth-stocks-you.html',
#   'providerPublishTime': 1641039300,
#   'type': 'STORY'},
#  {'uuid': '9a2761f6-0633-32eb-a4c9-fb47dbfb685c',
#   'title': 'The Five Best Dow Jones Stocks Of 2021',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/9a2761f6-0633-32eb-a4c9-fb47dbfb685c/the-five-best-dow-jones.html',
#   'providerPublishTime': 1640990023,
#   'type': 'STORY'},
# ...

# %%
datos = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
datos
# Out:
#             Adj Close                  Close                   High  \
#                  AAPL         SPY       AAPL         SPY       AAPL
# Date
# 2017-01-03  27.332472  206.146179  29.037500  225.240005  29.082500
# 2017-01-04  27.301880  207.372604  29.004999  226.580002  29.127501
# 2017-01-05  27.440722  207.207870  29.152500  226.399994  29.215000
# 2017-01-06  27.746637  207.949219  29.477501  227.210007  29.540001
# 2017-01-09  28.000780  207.262787  29.747499  226.460007  29.857500
# ...               ...         ...        ...         ...        ...
# 2017-04-24  33.947979  218.009232  35.910000  237.169998  35.987499
# 2017-04-25  34.158318  219.277710  36.132500  238.550003  36.224998
# 2017-04-26  33.957432  219.139832  35.919998  238.399994  36.150002
# 2017-04-27  33.983421  219.323700  35.947498  238.600006  36.040001
# 2017-04-28  33.950340  218.845703  35.912498  238.080002  36.075001
#
#                               Low                   Open              \
# ...

# %%
acciones=yf.download("TEF.MC SAB.MC", period="1d")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
acciones
# Out:
#            Adj Close          Close           High            Low          \
#               SAB.MC TEF.MC  SAB.MC TEF.MC  SAB.MC TEF.MC  SAB.MC  TEF.MC
# Date
# 2021-12-30    0.5918  3.852  0.5918  3.852  0.5946   3.89  0.5878  3.8445
#
#              Open           Volume
#            SAB.MC TEF.MC    SAB.MC    TEF.MC
# Date
# 2021-12-30   0.59  3.889  14101234  17050331

# %%
type(acciones)
# Out:
# pandas.core.frame.DataFrame

# %%
acciones["Close"]
# Out:
#             SAB.MC  TEF.MC
# Date
# 2021-12-30  0.5918   3.852

# %%
acciones["Close"]["TEF.MC"]
# Out:
# Date
# 2021-12-30    3.852
# Name: TEF.MC, dtype: float64

# %%
type(acciones["Close"]["TEF.MC"])
# Out:
# pandas.core.series.Series

# %%
acciones["Close"]["TEF.MC"][0]
# Out:
# 3.8519999980926514

# %%
type(acciones["Close"]["TEF.MC"][0])
# Out:
# numpy.float64

# %%
acciones2=yf.download("TEF.MC SAB.MC", period="1d",group_by="ticker")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
acciones2
# Out:
#            TEF.MC                                          SAB.MC          \
#              Open  High     Low  Close Adj Close    Volume   Open    High
# Date
# 2021-12-30  3.889  3.89  3.8445  3.852     3.852  17050331   0.59  0.5946
#
#
#                Low   Close Adj Close    Volume
# Date
# 2021-12-30  0.5878  0.5918    0.5918  14101234

# %%
acciones2["TEF.MC"]["Close"][0]
# Out:
# 3.8519999980926514

# %% [markdown]
# Para la siguiente sentencia hace falta tener instalado el módulo openpyxl. La última versión a 1/1/2022 es la 3.0.9

# %%
hist.to_excel("hola.xlsx", sheet_name="MSFT")
